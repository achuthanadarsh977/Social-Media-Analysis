# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score

# %%
#Load and preprocess data
q = pd.read_csv(r'C:\Users\SriniAchuthan\OneDrive\Documents\Data Analysis Intern\social_media_usage_1000.csv')
print(q.head())
print(q.tail())
print(q.dtypes)
print(q.shape)
# Out:
#    User_ID   Age  Gender  Instagram_hrs  Facebook_hrs  YouTube_hrs  \
# 0        1  51.0    Male            0.8           2.1          1.2
# 1        2  41.0  Female            2.6           2.2          3.5
# 2        3   NaN    Male            3.5           1.3          3.6
# 3        4  55.0  Female            3.2           1.4          0.6
# 4        5  20.0  Female            NaN           0.3          4.4
#
#        Purpose  Location Device_Type  Daily_Sessions
# 0    Education     Urban     Desktop               5
# 1          NaN  Suburban     Desktop              11
# 2  Socializing     Rural      Mobile               2
# 3         Work     Rural      Mobile               1
# 4  Socializing     Urban      Mobile               2
#      User_ID   Age  Gender  Instagram_hrs  Facebook_hrs  YouTube_hrs  \
# 995      996  17.0    Male            3.7           1.7          1.2
# 996      997  35.0    Male            2.0           2.4          1.6
# ...

# %%
q1 = pd.read_csv(r'C:\Users\SriniAchuthan\Downloads\social_media_usage_1000(in).csv')
q1 = pd.DataFrame(q1)
sns.boxplot(x='Gender',y='Total_hrs',data=q1)
# Out:
# <Axes: xlabel='Gender', ylabel='Total_hrs'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'q' is your DataFrame with the 3 columns
# ['Facebook_hrs', 'Instagram_hrs', 'YouTube_hrs']

# Select the relevant columns
platform_data = q[['Facebook_hrs', 'Instagram_hrs', 'YouTube_hrs']]

# Create a boxplot
plt.figure(figsize=(8,6))
platform_data.boxplot()

# Labeling
plt.title('Distribution of Time Spent on Social Media Platforms')
plt.ylabel('Hours per day')
plt.xlabel('Platform')

# Show plot
plt.show()

# %%
sns.boxplot(x="Gender",y="Facebook_hrs",data=q)
# Out:
# <Axes: xlabel='Gender', ylabel='Facebook_hrs'>

# %%
sns.scatterplot(x = 'Age',y = 'Total_hrs',data=q1)
# Out:
# <Axes: xlabel='Age', ylabel='Total_hrs'>

# %%
w = q1.dropna()
print(w)
# Out:
#      User_ID   Age  Gender  Instagram_hrs  Facebook_hrs  YouTube_hrs  \
# 0          1  51.0    Male            0.8           2.1          1.2
# 3          4  55.0  Female            3.2           1.4          0.6
# 5          6  33.0  Female            3.5           1.2          3.2
# 6          7  51.0  Female            2.1           2.2          4.2
# 7          8  31.0    Male            1.7           2.0          0.9
# ..       ...   ...     ...            ...           ...          ...
# 994      995  22.0   Other            2.5           0.3          4.0
# 995      996  17.0    Male            3.7           1.7          1.2
# 996      997  35.0    Male            2.0           2.4          1.6
# 997      998  22.0  Female            2.7           1.9          3.7
# 998      999  56.0    Male            0.9           1.5          1.8
#
#            Purpose  Location Device_Type  Daily_Sessions  Total_hrs
# 0        Education     Urban     Desktop               5        4.1
# ...

# %%
print(w.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 727 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User_ID         727 non-null    int64
#  1   Age             727 non-null    float64
#  2   Gender          727 non-null    object
#  3   Instagram_hrs   727 non-null    float64
#  4   Facebook_hrs    727 non-null    float64
#  5   YouTube_hrs     727 non-null    float64
#  6   Purpose         727 non-null    object
#  7   Location        727 non-null    object
#  8   Device_Type     727 non-null    object
#  9   Daily_Sessions  727 non-null    int64
#  10  Total_hrs       727 non-null    float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 68.2+ KB
# None

# %%
print(w)
# Out:
#      User_ID   Age  Gender  Instagram_hrs  Facebook_hrs  YouTube_hrs  \
# 0          1  51.0    Male            0.8           2.1          1.2
# 3          4  55.0  Female            3.2           1.4          0.6
# 5          6  33.0  Female            3.5           1.2          3.2
# 6          7  51.0  Female            2.1           2.2          4.2
# 7          8  31.0    Male            1.7           2.0          0.9
# ..       ...   ...     ...            ...           ...          ...
# 994      995  22.0   Other            2.5           0.3          4.0
# 995      996  17.0    Male            3.7           1.7          1.2
# 996      997  35.0    Male            2.0           2.4          1.6
# 997      998  22.0  Female            2.7           1.9          3.7
# 998      999  56.0    Male            0.9           1.5          1.8
#
#            Purpose  Location Device_Type  Daily_Sessions  Total_hrs
# 0        Education     Urban     Desktop               5        4.1
# ...

# %%
sns.boxplot(x = "Total_hrs" , y = "Purpose" , data=w)
# Out:
# <Axes: xlabel='Total_hrs', ylabel='Purpose'>

# %%
sns.boxplot(x="Device_Type",y="Daily_Sessions",data=w)
# Out:
# <Axes: xlabel='Device_Type', ylabel='Daily_Sessions'>

# %%
sns.barplot(x="Location" , y="Total_hrs" ,  data = w )
# Out:
# <Axes: xlabel='Location', ylabel='Total_hrs'>

# %%
#Case Study 1: Top User
print(w.info())
s = w['Total_hrs'].idxmax()
df = w.loc[s]

print("\nTop user details")
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 727 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User_ID         727 non-null    int64
#  1   Age             727 non-null    float64
#  2   Gender          727 non-null    object
#  3   Instagram_hrs   727 non-null    float64
#  4   Facebook_hrs    727 non-null    float64
#  5   YouTube_hrs     727 non-null    float64
#  6   Purpose         727 non-null    object
#  7   Location        727 non-null    object
#  8   Device_Type     727 non-null    object
#  9   Daily_Sessions  727 non-null    int64
#  10  Total_hrs       727 non-null    float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 84.3+ KB
# None
#
# Top user details
# User_ID                   865
# Age                      55.0
# Gender                 Female
# Instagram_hrs             4.0
# Facebook_hrs              3.3
# YouTube_hrs               4.0
# ...

# %%
#Case Study 2: Young Minimalist
# Sample code to locate a young user with least total usage
# First filter users with Age < 18
# Then find the one with the lowest Total_Hours among them

w = w[w['Age'] < 18]
e = w['Total_hrs'].idxmin()
e1 = w.loc[e]
print("Young Minimalist")
print(e1)
# Out:
# Young Minimalist
# User_ID                   492
# Age                      14.0
# Gender                  Other
# Instagram_hrs             1.0
# Facebook_hrs              0.0
# YouTube_hrs               1.1
# Purpose           Socializing
# Location             Suburban
# Device_Type            Tablet
# Daily_Sessions              2
# Total_hrs                 2.1
# Name: 491, dtype: object
